# %% [markdown]
# ## Part 1: Setting Up
#
# ✨This is a Jupyter Notebook that allows you to run Python code interactively 🐍✨
#
# 1. Click the **Select Kernel** button on the top right of the notebook.
# 2. Choose **Python environments** and select **Python 3.11**.
#
# Note: To run the code in the cells of this notebook click the play button (▶️) on the left side of the cells that contain code.
#
# These are instructions for the insructor led AI Tour session, you should have the Skillable Lab Manual open in a different tab.
#
# Copy/Paste the `CREDENTIALS` block at the top of the Skillable Lab instructions below:

# %%
Username     = "User1-44726673@LODSPRODMCA.onmicrosoft.com"

Password     = "eBhD0e!0D!"

AzureEnvName = "AITOUR44726673"

Subscription = "bc134f78-6499-418b-b998-ccd3b734eca8"

# %% [markdown]
# ### a. Login to GitHub.com and fork repository
#
# We'll begin by logging into the Github CLI so we can fork the repository and make changes to the code comfortably.

# %% [markdown]
# > Running this command will:
# >   - Log in to the **GitHub.com** account
# >   - Select **HTTPS** as the preferred protocol for Git operations
# >   - Authenticate Git with your GitHub credentials
# >   - Authenticate GitHub CLI using **a web browser**
#
# Click the play button to the left of the cell to run it and then complete the authorization process.

# %%
! echo Y | GITHUB_TOKEN="" gh auth login --hostname github.com --git-protocol https --web
# Out:
# ! First copy your one-time code: 56AF-98E1
# Open this URL to continue in your web browser: https://github.com/login/device
# ✓ Authentication complete.
# - gh config set -h github.com git_protocol https
# ✓ Configured git protocol
# ! Authentication credentials saved in plain text
# ✓ Logged in as marlenezw

# %% [markdown]
# Then fork the repository

# %%
! GITHUB_TOKEN="" gh repo fork --remote
# Out:
# ✓ Created fork marlenezw/contoso-creative-writer
# ✓ Added remote origin

# %% [markdown]
# ### b. Login to Azure
#
# We will login to Azure Developer CLI (azd) and Azure CLI (az).
#
# 1. Sign in to Azure Developer CLI (azd)

# %%
! az login -u $Username -p $Password
# Out:
# Authentication with username and password in the command line is strongly discouraged. Use one of the recommended authentication methods based on your requirements. For more details, see https://go.microsoft.com/fwlink/?linkid=2276314
# [
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "4cfe372a-37a4-44f8-91b2-5faf34253c62",
#     "id": "bc134f78-6499-418b-b998-ccd3b734eca8",
#     "isDefault": true,
#     "managedByTenants": [],
#     "name": "AIDay-lod49713120",
#     "state": "Enabled",
#     "tenantDefaultDomain": "LODSPRODMCA.onmicrosoft.com",
#     "tenantDisplayName": "LODS-Prod-MCA",
#     "tenantId": "4cfe372a-37a4-44f8-91b2-5faf34253c62",
#     "user": {
#       "name": "User1-44726673@LODSPRODMCA.onmicrosoft.com",
#       "type": "user"
#     }
#   }
# ]

# %% [markdown]
# 2. Sign in to Azure Developer CLI.
#
#     > **🚧 IMPORTANT**: Use the following `username` and `password` when prompted to sign in with an email and password.

# %%
from IPython.display import Markdown
Markdown(f"- **Username**: `{Username}`\n - **Password**: `{Password}`")
# Out:
# - **Username**: `User1-44726673@LODSPRODMCA.onmicrosoft.com`
#  - **Password**: `eBhD0e!0D!`

# %%
! azd auth login --use-device-code --no-prompt
# Out:
# Start by copying the next code: DH2HR352X
# Then, go to: https://microsoft.com/devicelogin
# Waiting for you to complete authentication in the browser...
# Device code authentication completed.
# Logged in to Azure.ing subscriptions...

# %% [markdown]
# 3.  Next we will get the environment variables for your resource group.
#
#     > **🚧 IMPORTANT**: You will need to run the output of the next cell **in the terminal!**
#     >
#     > - Run the cell below and then copy the output and paste it in the terminal and press enter
#     > - Select `Y` when asked if you'd like to create the environment
#     > - Press enter to select the default subscription
#     > - Select `Canada East` as the location
#
#     > **It's important that you select the correct location (Canada East)**

# %%
from IPython.display import Markdown
Markdown(f"azd env refresh -e {AzureEnvName}")
# Out:
# azd env refresh -e AITOUR44726673

# %% [markdown]
# Once the command has been successfully run, continue with step 4, running the cells in the notebook as before.

# %% [markdown]
# 4. Save the environment variables to a .env file.

# %%
! azd env get-values > ../../.env

# %% [markdown]
# The refreshed environment variables should have been saved to the [.env](../../.env)

# %% [markdown]
# 5. Set the correct roles by running the roles bash script.

# %%
! bash ../../infra/hooks/roles.sh
# Out:
# {
#   "condition": null,
#   "conditionVersion": null,
#   "createdBy": null,
#   "createdOn": "2024-10-11T10:21:06.449409+00:00",
#   "delegatedManagedIdentityResourceId": null,
#   "description": null,
#   "id": "/subscriptions/bc134f78-6499-418b-b998-ccd3b734eca8/resourceGroups/rg-AITOUR44726673/providers/Microsoft.Authorization/roleAssignments/82442d93-fb38-4d7c-a445-910845e0a777",
#   "name": "82442d93-fb38-4d7c-a445-910845e0a777",
#   "principalId": "843c334f-64c4-4268-a556-7f1f104bf037",
#   "principalType": "User",
#   "resourceGroup": "rg-AITOUR44726673",
#   "roleDefinitionId": "/subscriptions/bc134f78-6499-418b-b998-ccd3b734eca8/providers/Microsoft.Authorization/roleDefinitions/8ebe5a00-799e-43f5-93ac-243d3dce84a7",
#   "scope": "/subscriptions/bc134f78-6499-418b-b998-ccd3b734eca8/resourceGroups/rg-AITOUR44726673",
#   "type": "Microsoft.Authorization/roleAssignments",
#   "updatedBy": "843c334f-64c4-4268-a556-7f1f104bf037",
#   "updatedOn": "2024-10-11T10:21:07.053415+00:00"
# }
# {
#   "condition": null,
#   "conditionVersion": null,
#   "createdBy": null,
#   "createdOn": "2024-10-11T10:21:08.944963+00:00",
#   "delegatedManagedIdentityResourceId": null,
#   "description": null,
#   "id": "/subscriptions/bc134f78-6499-418b-b998-ccd3b734eca8/resourceGroups/rg-AITOUR44726673/providers/Microsoft.Authorization/roleAssignments/3a76b505-1a2b-46d6-8fb2-cecc07a1cd81",
#   "name": "3a76b505-1a2b-46d6-8fb2-cecc07a1cd81",
#   "principalId": "843c334f-64c4-4268-a556-7f1f104bf037",
#   "principalType": "User",
#   "resourceGroup": "rg-AITOUR44726673",
#   "roleDefinitionId": "/subscriptions/bc134f78-6499-418b-b998-ccd3b734eca8/providers/Microsoft.Authorization/roleDefinitions/1407120a-92aa-4202-b7e9-c0e197c71c8f",
#   "scope": "/subscriptions/bc134f78-6499-418b-b998-ccd3b734eca8/resourceGroups/rg-AITOUR44726673",
#   "type": "Microsoft.Authorization/roleAssignments",
#   "updatedBy": "843c334f-64c4-4268-a556-7f1f104bf037",
#   "updatedOn": "2024-10-11T10:21:09.550983+00:00"
# }
# {
#   "condition": null,
#   "conditionVersion": null,
#   "createdBy": "69d563db-e4f3-4bd3-be8c-44926ea56a7d",
#   "createdOn": "2024-10-11T09:44:55.230459+00:00",
#   "delegatedManagedIdentityResourceId": null,
#   "description": null,
#   "id": "/subscriptions/bc134f78-6499-418b-b998-ccd3b734eca8/resourcegroups/rg-AITOUR44726673/providers/Microsoft.Authorization/roleAssignments/7a37665d-b450-5262-ab41-4807dcb452f3",
#   "name": "7a37665d-b450-5262-ab41-4807dcb452f3",
#   "principalId": "69d563db-e4f3-4bd3-be8c-44926ea56a7d",
#   "principalName": "https://lodazurepass.onmicrosoft.com/45587fa8-5f05-46d9-8d71-595d74062152",
#   "principalType": "ServicePrincipal",
#   "resourceGroup": "rg-AITOUR44726673",
#   "roleDefinitionId": "/subscriptions/bc134f78-6499-418b-b998-ccd3b734eca8/providers/Microsoft.Authorization/roleDefinitions/8ebe5a00-799e-43f5-93ac-243d3dce84a7",
#   "roleDefinitionName": "Search Index Data Contributor",
#   "scope": "/subscriptions/bc134f78-6499-418b-b998-ccd3b734eca8/resourcegroups/rg-AITOUR44726673",
#   "type": "Microsoft.Authorization/roleAssignments",
#   "updatedBy": "69d563db-e4f3-4bd3-be8c-44926ea56a7d",
#   "updatedOn": "2024-10-11T09:44:55.717503+00:00"
# }
# {
#   "condition": null,
#   "conditionVersion": null,
#   "createdBy": null,
#   "createdOn": "2024-10-11T10:21:15.115046+00:00",
#   "delegatedManagedIdentityResourceId": null,
#   "description": null,
#   "id": "/subscriptions/bc134f78-6499-418b-b998-ccd3b734eca8/resourceGroups/rg-AITOUR44726673/providers/Microsoft.Authorization/roleAssignments/99d4770b-f4a8-4124-97ba-01d17fce5086",
#   "name": "99d4770b-f4a8-4124-97ba-01d17fce5086",
#   "principalId": "843c334f-64c4-4268-a556-7f1f104bf037",
#   "principalType": "User",
#   "resourceGroup": "rg-AITOUR44726673",
#   "roleDefinitionId": "/subscriptions/bc134f78-6499-418b-b998-ccd3b734eca8/providers/Microsoft.Authorization/roleDefinitions/5e0bd9bd-7b93-4f28-af87-19fc36ad61bd",
#   "scope": "/subscriptions/bc134f78-6499-418b-b998-ccd3b734eca8/resourceGroups/rg-AITOUR44726673",
#   "type": "Microsoft.Authorization/roleAssignments",
#   "updatedBy": "843c334f-64c4-4268-a556-7f1f104bf037",
#   "updatedOn": "2024-10-11T10:21:15.546396+00:00"
# }

# %% [markdown]
# 6. Run the postprovision script by running the cell below
#
# > ⏰ **TIP to save time**:
# > - You do not need to wait until the script completes to start working on the first notebook.
# > - Head to [workshop-1-intro.ipynb](workshop-1-intro.ipynb) once you've run the cell below and get started!

# %%
! echo 1 | azd hooks run postprovision -e $AzureEnvName
# Out:
# Running hooks (azd hooks run)
# Finding and executing postprovision hooks for environment AITOUR44726673.
#
# Running 1 postprovision command hook(s) for project
#   Running 1 postprovision command hook(s) for project
#
#   ──── Project: postprovision Hook Output ──────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
# ─────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#   Building creativeagentapi:20241011-102125 using ./src/api/ ...
#
# ─────────────────────────────────────────────────────────────────────
#
#
#
#
#
#   Building creativeagentapi:20241011-102125 using ./src/api/ ...
#   2024/10/11 10:21:31 Downloading source code...
#
# ─────────────────────────────────────────────────────────────────────
#
#
#
#
#   Building creativeagentapi:20241011-102125 using ./src/api/ ...
#   2024/10/11 10:21:31 Downloading source code...
#   2024/10/11 10:21:31 Finished downloading source code
#
# ─────────────────────────────────────────────────────────────────────
#
#
#   Building creativeagentapi:20241011-102125 using ./src/api/ ...
#   2024/10/11 10:21:31 Downloading source code...
#   2024/10/11 10:21:31 Finished downloading source code
#   2024/10/11 10:21:32 Using acb_vol_91bf0bd6-cbbc-4a0c-89c1-3ffb87641706 as the
#   home volume
#
# ─────────────────────────────────────────────────────────────────────
#
#   Building creativeagentapi:20241011-102125 using ./src/api/ ...
#   2024/10/11 10:21:31 Downloading source code...
#   2024/10/11 10:21:31 Finished downloading source code
#   2024/10/11 10:21:32 Using acb_vol_91bf0bd6-cbbc-4a0c-89c1-3ffb87641706 as the
#   home volume
#   2024/10/11 10:21:32 Setting up Docker configuration...
#
# ─────────────────────────────────────────────────────────────────────
#   Building creativeagentapi:20241011-102125 using ./src/api/ ...
#   2024/10/11 10:21:31 Downloading source code...
#   2024/10/11 10:21:31 Finished downloading source code
#   2024/10/11 10:21:32 Using acb_vol_91bf0bd6-cbbc-4a0c-89c1-3ffb87641706 as the
#   home volume
#   2024/10/11 10:21:32 Setting up Docker configuration...
#   2024/10/11 10:21:32 Successfully set up Docker configuration
#
#   Building creativeagentapi:20241011-102125 using ./src/api/ ...─────────────
#   2024/10/11 10:21:31 Downloading source code...
#   2024/10/11 10:21:31 Finished downloading source code
#   2024/10/11 10:21:32 Using acb_vol_91bf0bd6-cbbc-4a0c-89c1-3ffb87641706 as the
#   home volume
#   2024/10/11 10:21:32 Setting up Docker configuration...
#   2024/10/11 10:21:32 Successfully set up Docker configuration
#   2024/10/11 10:21:32 Logging in to registry: cr44726673.azurecr.io
#
#   2024/10/11 10:21:31 Downloading source code...─────────────────────────────
#   2024/10/11 10:21:31 Finished downloading source code
#   2024/10/11 10:21:32 Using acb_vol_91bf0bd6-cbbc-4a0c-89c1-3ffb87641706 as the
#   home volume
#   2024/10/11 10:21:32 Setting up Docker configuration...
#   2024/10/11 10:21:32 Successfully set up Docker configuration
#   2024/10/11 10:21:32 Logging in to registry: cr44726673.azurecr.io
#   2024/10/11 10:21:33 Successfully logged into cr44726673.azurecr.io
#
#   2024/10/11 10:21:32 Using acb_vol_91bf0bd6-cbbc-4a0c-89c1-3ffb87641706 as the
#   home volume
#   2024/10/11 10:21:32 Setting up Docker configuration...
#   2024/10/11 10:21:32 Successfully set up Docker configuration
#   2024/10/11 10:21:32 Logging in to registry: cr44726673.azurecr.io
#   2024/10/11 10:21:33 Successfully logged into cr44726673.azurecr.io
#   2024/10/11 10:21:33 Executing step ID: build. Timeout(sec): 28800, Working dir
#   ectory: '', Network: ''
#
#   home volume────────────────────────────────────────────────────────────────
#   2024/10/11 10:21:32 Setting up Docker configuration...
#   2024/10/11 10:21:32 Successfully set up Docker configuration
#   2024/10/11 10:21:32 Logging in to registry: cr44726673.azurecr.io
#   2024/10/11 10:21:33 Successfully logged into cr44726673.azurecr.io
#   2024/10/11 10:21:33 Executing step ID: build. Timeout(sec): 28800, Working dir
#   ectory: '', Network: ''
#   2024/10/11 10:21:33 Scanning for dependencies...
#
#   2024/10/11 10:21:32 Setting up Docker configuration...─────────────────────
#   2024/10/11 10:21:32 Successfully set up Docker configuration
#   2024/10/11 10:21:32 Logging in to registry: cr44726673.azurecr.io
#   2024/10/11 10:21:33 Successfully logged into cr44726673.azurecr.io
#   2024/10/11 10:21:33 Executing step ID: build. Timeout(sec): 28800, Working dir
#   ectory: '', Network: ''
#   2024/10/11 10:21:33 Scanning for dependencies...
#   2024/10/11 10:21:33 Successfully scanned dependencies
#
#   2024/10/11 10:21:32 Successfully set up Docker configuration───────────────
#   2024/10/11 10:21:32 Logging in to registry: cr44726673.azurecr.io
#   2024/10/11 10:21:33 Successfully logged into cr44726673.azurecr.io
#   2024/10/11 10:21:33 Executing step ID: build. Timeout(sec): 28800, Working dir
#   ectory: '', Network: ''
#   2024/10/11 10:21:33 Scanning for dependencies...
#   2024/10/11 10:21:33 Successfully scanned dependencies
#   2024/10/11 10:21:33 Launching container with name: build
#
#   2024/10/11 10:21:32 Logging in to registry: cr44726673.azurecr.io──────────
#   2024/10/11 10:21:33 Successfully logged into cr44726673.azurecr.io
#   2024/10/11 10:21:33 Executing step ID: build. Timeout(sec): 28800, Working dir
#   ectory: '', Network: ''
#   2024/10/11 10:21:33 Scanning for dependencies...
#   2024/10/11 10:21:33 Successfully scanned dependencies
#   2024/10/11 10:21:33 Launching container with name: build
#   Sending build context to Docker daemon  88.06kB
#
#   2024/10/11 10:21:33 Successfully logged into cr44726673.azurecr.io─────────
#   2024/10/11 10:21:33 Executing step ID: build. Timeout(sec): 28800, Working dir
#   ectory: '', Network: ''
#   2024/10/11 10:21:33 Scanning for dependencies...
#   2024/10/11 10:21:33 Successfully scanned dependencies
#   2024/10/11 10:21:33 Launching container with name: build
#   Sending build context to Docker daemon  88.06kB
#   Step 1/7 : FROM  python:3.11-slim
#
#   2024/10/11 10:21:33 Executing step ID: build. Timeout(sec): 28800, Working dir
#   ectory: '', Network: ''
#   2024/10/11 10:21:33 Scanning for dependencies...
#   2024/10/11 10:21:33 Successfully scanned dependencies
#   2024/10/11 10:21:33 Launching container with name: build
#   Sending build context to Docker daemon  88.06kB
#   Step 1/7 : FROM  python:3.11-slim
#   3.11-slim: Pulling from library/python
#
#   ectory: '', Network: ''────────────────────────────────────────────────────
#   2024/10/11 10:21:33 Scanning for dependencies...
#   2024/10/11 10:21:33 Successfully scanned dependencies
#   2024/10/11 10:21:33 Launching container with name: build
#   Sending build context to Docker daemon  88.06kB
#   Step 1/7 : FROM  python:3.11-slim
#   3.11-slim: Pulling from library/python
#   302e3ee49805: Pulling fs layer
#
#   2024/10/11 10:21:33 Scanning for dependencies...───────────────────────────
#   2024/10/11 10:21:33 Successfully scanned dependencies
#   2024/10/11 10:21:33 Launching container with name: build
#   Sending build context to Docker daemon  88.06kB
#   Step 1/7 : FROM  python:3.11-slim
#   3.11-slim: Pulling from library/python
#   302e3ee49805: Pulling fs layer
#   4aeebc636537: Pulling fs layer
#
#   2024/10/11 10:21:33 Successfully scanned dependencies──────────────────────
#   2024/10/11 10:21:33 Launching container with name: build
#   Sending build context to Docker daemon  88.06kB
#   Step 1/7 : FROM  python:3.11-slim
#   3.11-slim: Pulling from library/python
#   302e3ee49805: Pulling fs layer
#   4aeebc636537: Pulling fs layer
#   2aee89346c42: Pulling fs layer
#
#   2024/10/11 10:21:33 Launching container with name: build───────────────────
#   Sending build context to Docker daemon  88.06kB
#   Step 1/7 : FROM  python:3.11-slim
#   3.11-slim: Pulling from library/python
#   302e3ee49805: Pulling fs layer
#   4aeebc636537: Pulling fs layer
#   2aee89346c42: Pulling fs layer
#   0538735e543f: Pulling fs layer
#
#   Sending build context to Docker daemon  88.06kB────────────────────────────
#   Step 1/7 : FROM  python:3.11-slim
#   3.11-slim: Pulling from library/python
#   302e3ee49805: Pulling fs layer
#   4aeebc636537: Pulling fs layer
#   2aee89346c42: Pulling fs layer
#   0538735e543f: Pulling fs layer
#   0538735e543f: Waiting
#
#   Step 1/7 : FROM  python:3.11-slim──────────────────────────────────────────
#   3.11-slim: Pulling from library/python
#   302e3ee49805: Pulling fs layer
#   4aeebc636537: Pulling fs layer
#   2aee89346c42: Pulling fs layer
#   0538735e543f: Pulling fs layer
#   0538735e543f: Waiting
#   4aeebc636537: Verifying Checksum
#
#   3.11-slim: Pulling from library/python─────────────────────────────────────
#   302e3ee49805: Pulling fs layer
#   4aeebc636537: Pulling fs layer
#   2aee89346c42: Pulling fs layer
#   0538735e543f: Pulling fs layer
#   0538735e543f: Waiting
#   4aeebc636537: Verifying Checksum
#   4aeebc636537: Download complete
#
#   302e3ee49805: Pulling fs layer─────────────────────────────────────────────
#   4aeebc636537: Pulling fs layer
#   2aee89346c42: Pulling fs layer
#   0538735e543f: Pulling fs layer
#   0538735e543f: Waiting
#   4aeebc636537: Verifying Checksum
#   4aeebc636537: Download complete
#   2aee89346c42: Verifying Checksum
#
#   4aeebc636537: Pulling fs layer─────────────────────────────────────────────
#   2aee89346c42: Pulling fs layer
#   0538735e543f: Pulling fs layer
#   0538735e543f: Waiting
#   4aeebc636537: Verifying Checksum
#   4aeebc636537: Download complete
#   2aee89346c42: Verifying Checksum
#   2aee89346c42: Download complete
#
#   2aee89346c42: Pulling fs layer─────────────────────────────────────────────
#   0538735e543f: Pulling fs layer
#   0538735e543f: Waiting
#   4aeebc636537: Verifying Checksum
#   4aeebc636537: Download complete
#   2aee89346c42: Verifying Checksum
#   2aee89346c42: Download complete
#   0538735e543f: Verifying Checksum
#
#   0538735e543f: Pulling fs layer─────────────────────────────────────────────
#   0538735e543f: Waiting
#   4aeebc636537: Verifying Checksum
#   4aeebc636537: Download complete
#   2aee89346c42: Verifying Checksum
#   2aee89346c42: Download complete
#   0538735e543f: Verifying Checksum
#   0538735e543f: Download complete
#
#   0538735e543f: Waiting──────────────────────────────────────────────────────
#   4aeebc636537: Verifying Checksum
#   4aeebc636537: Download complete
#   2aee89346c42: Verifying Checksum
#   2aee89346c42: Download complete
#   0538735e543f: Verifying Checksum
#   0538735e543f: Download complete
#   302e3ee49805: Verifying Checksum
#
#   4aeebc636537: Verifying Checksum───────────────────────────────────────────
#   4aeebc636537: Download complete
#   2aee89346c42: Verifying Checksum
#   2aee89346c42: Download complete
#   0538735e543f: Verifying Checksum
#   0538735e543f: Download complete
#   302e3ee49805: Verifying Checksum
#   302e3ee49805: Download complete
#
#   4aeebc636537: Download complete────────────────────────────────────────────
#   2aee89346c42: Verifying Checksum
#   2aee89346c42: Download complete
#   0538735e543f: Verifying Checksum
#   0538735e543f: Download complete
#   302e3ee49805: Verifying Checksum
#   302e3ee49805: Download complete
#   302e3ee49805: Pull complete
#
#   2aee89346c42: Verifying Checksum───────────────────────────────────────────
#   2aee89346c42: Download complete
#   0538735e543f: Verifying Checksum
#   0538735e543f: Download complete
#   302e3ee49805: Verifying Checksum
#   302e3ee49805: Download complete
#   302e3ee49805: Pull complete
#   4aeebc636537: Pull complete
#
#   2aee89346c42: Download complete────────────────────────────────────────────
#   0538735e543f: Verifying Checksum
#   0538735e543f: Download complete
#   302e3ee49805: Verifying Checksum
#   302e3ee49805: Download complete
#   302e3ee49805: Pull complete
#   4aeebc636537: Pull complete
#   2aee89346c42: Pull complete
#
#   0538735e543f: Verifying Checksum───────────────────────────────────────────
#   0538735e543f: Download complete
#   302e3ee49805: Verifying Checksum
#   302e3ee49805: Download complete
#   302e3ee49805: Pull complete
#   4aeebc636537: Pull complete
#   2aee89346c42: Pull complete
#   0538735e543f: Pull complete
#
#   302e3ee49805: Verifying Checksum───────────────────────────────────────────
#   302e3ee49805: Download complete
#   302e3ee49805: Pull complete
#   4aeebc636537: Pull complete
#   2aee89346c42: Pull complete
#   0538735e543f: Pull complete
#   Digest: sha256:5501a4fe605abe24de87c2f3d6cf9fd760354416a0cad0296cf284fddcdca9e
#   2
#
#   302e3ee49805: Download complete────────────────────────────────────────────
#   302e3ee49805: Pull complete
#   4aeebc636537: Pull complete
#   2aee89346c42: Pull complete
#   0538735e543f: Pull complete
#   Digest: sha256:5501a4fe605abe24de87c2f3d6cf9fd760354416a0cad0296cf284fddcdca9e
#   2
#   Status: Downloaded newer image for python:3.11-slim
#
#   302e3ee49805: Pull complete────────────────────────────────────────────────
#   4aeebc636537: Pull complete
#   2aee89346c42: Pull complete
#   0538735e543f: Pull complete
#   Digest: sha256:5501a4fe605abe24de87c2f3d6cf9fd760354416a0cad0296cf284fddcdca9e
#   2
#   Status: Downloaded newer image for python:3.11-slim
#    ---> 496b61236826
#
#   4aeebc636537: Pull complete────────────────────────────────────────────────
#   2aee89346c42: Pull complete
#   0538735e543f: Pull complete
#   Digest: sha256:5501a4fe605abe24de87c2f3d6cf9fd760354416a0cad0296cf284fddcdca9e
#   2
#   Status: Downloaded newer image for python:3.11-slim
#    ---> 496b61236826
#   Step 2/7 : WORKDIR /app
#
#   2aee89346c42: Pull complete────────────────────────────────────────────────
#   0538735e543f: Pull complete
#   Digest: sha256:5501a4fe605abe24de87c2f3d6cf9fd760354416a0cad0296cf284fddcdca9e
#   2
#   Status: Downloaded newer image for python:3.11-slim
#    ---> 496b61236826
#   Step 2/7 : WORKDIR /app
#    ---> Running in 4d4ad3ff2073
#
#   0538735e543f: Pull complete────────────────────────────────────────────────
#   Digest: sha256:5501a4fe605abe24de87c2f3d6cf9fd760354416a0cad0296cf284fddcdca9e
#   2
#   Status: Downloaded newer image for python:3.11-slim
#    ---> 496b61236826
#   Step 2/7 : WORKDIR /app
#    ---> Running in 4d4ad3ff2073
#   Removing intermediate container 4d4ad3ff2073
#
#   Digest: sha256:5501a4fe605abe24de87c2f3d6cf9fd760354416a0cad0296cf284fddcdca9e
#   2
#   Status: Downloaded newer image for python:3.11-slim
#    ---> 496b61236826
#   Step 2/7 : WORKDIR /app
#    ---> Running in 4d4ad3ff2073
#   Removing intermediate container 4d4ad3ff2073
#    ---> 81c4f988ddae
#
#   2A─────────────────────────────────────────────────────────────────────
#   Status: Downloaded newer image for python:3.11-slim
#    ---> 496b61236826
#   Step 2/7 : WORKDIR /app
#    ---> Running in 4d4ad3ff2073
#   Removing intermediate container 4d4ad3ff2073
#    ---> 81c4f988ddae
#   Step 3/7 : COPY requirements.txt .
#
#   Status: Downloaded newer image for python:3.11-slim────────────────────────
#    ---> 496b61236826
#   Step 2/7 : WORKDIR /app
#    ---> Running in 4d4ad3ff2073
#   Removing intermediate container 4d4ad3ff2073
#    ---> 81c4f988ddae
#   Step 3/7 : COPY requirements.txt .
#    ---> 30704a7b5d97
#
#    ---> 496b61236826─────────────────────────────────────────────────────────
#   Step 2/7 : WORKDIR /app
#    ---> Running in 4d4ad3ff2073
#   Removing intermediate container 4d4ad3ff2073
#    ---> 81c4f988ddae
#   Step 3/7 : COPY requirements.txt .
#    ---> 30704a7b5d97
#   Step 4/7 : RUN pip install --no-cache-dir -r requirements.txt
#
#   Step 2/7 : WORKDIR /app────────────────────────────────────────────────────
#    ---> Running in 4d4ad3ff2073
#   Removing intermediate container 4d4ad3ff2073
#    ---> 81c4f988ddae
#   Step 3/7 : COPY requirements.txt .
#    ---> 30704a7b5d97
#   Step 4/7 : RUN pip install --no-cache-dir -r requirements.txt
#    ---> Running in 1be5ab3500c2
#
#    ---> Running in 4d4ad3ff2073──────────────────────────────────────────────
#   Removing intermediate container 4d4ad3ff2073
#    ---> 81c4f988ddae
#   Step 3/7 : COPY requirements.txt .
#    ---> 30704a7b5d97
#   Step 4/7 : RUN pip install --no-cache-dir -r requirements.txt
#    ---> Running in 1be5ab3500c2
#   Collecting fastapi (from -r requirements.txt (line 1))
#
#   Removing intermediate container 4d4ad3ff2073───────────────────────────────
#    ---> 81c4f988ddae
#   Step 3/7 : COPY requirements.txt .
#    ---> 30704a7b5d97
#   Step 4/7 : RUN pip install --no-cache-dir -r requirements.txt
#    ---> Running in 1be5ab3500c2
#   Collecting fastapi (from -r requirements.txt (line 1))
#     Downloading fastapi-0.115.0-py3-none-any.whl.metadata (27 kB)
#
#    ---> 81c4f988ddae─────────────────────────────────────────────────────────
#   Step 3/7 : COPY requirements.txt .
#    ---> 30704a7b5d97
#   Step 4/7 : RUN pip install --no-cache-dir -r requirements.txt
#    ---> Running in 1be5ab3500c2
#   Collecting fastapi (from -r requirements.txt (line 1))
#     Downloading fastapi-0.115.0-py3-none-any.whl.metadata (27 kB)
#   Collecting openai (from -r requirements.txt (line 3))
#
#   Step 3/7 : COPY requirements.txt .─────────────────────────────────────────
#    ---> 30704a7b5d97
#   Step 4/7 : RUN pip install --no-cache-dir -r requirements.txt
#    ---> Running in 1be5ab3500c2
#   Collecting fastapi (from -r requirements.txt (line 1))
#     Downloading fastapi-0.115.0-py3-none-any.whl.metadata (27 kB)
#   Collecting openai (from -r requirements.txt (line 3))
#     Downloading openai-1.51.2-py3-none-any.whl.metadata (24 kB)
#
#    ---> 30704a7b5d97─────────────────────────────────────────────────────────
#   Step 4/7 : RUN pip install --no-cache-dir -r requirements.txt
#    ---> Running in 1be5ab3500c2
#   Collecting fastapi (from -r requirements.txt (line 1))
#     Downloading fastapi-0.115.0-py3-none-any.whl.metadata (27 kB)
#   Collecting openai (from -r requirements.txt (line 3))
#     Downloading openai-1.51.2-py3-none-any.whl.metadata (24 kB)
#   Collecting requests (from -r requirements.txt (line 4))
#
#   Step 4/7 : RUN pip install --no-cache-dir -r requirements.txt──────────────
#    ---> Running in 1be5ab3500c2
#   Collecting fastapi (from -r requirements.txt (line 1))
#     Downloading fastapi-0.115.0-py3-none-any.whl.metadata (27 kB)
#   Collecting openai (from -r requirements.txt (line 3))
#     Downloading openai-1.51.2-py3-none-any.whl.metadata (24 kB)
#   Collecting requests (from -r requirements.txt (line 4))
#     Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
#
#   Collecting fastapi (from -r requirements.txt (line 1))─────────────────────
#     Downloading fastapi-0.115.0-py3-none-any.whl.metadata (27 kB)
#   Collecting openai (from -r requirements.txt (line 3))
#     Downloading openai-1.51.2-py3-none-any.whl.metadata (24 kB)
#   Collecting requests (from -r requirements.txt (line 4))
#     Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
#   Collecting prompty==0.1.24 (from prompty[azure]==0.1.24->-r requirements.txt (
#   line 5))
#
#     Downloading fastapi-0.115.0-py3-none-any.whl.metadata (27 kB)────────────
#   Collecting openai (from -r requirements.txt (line 3))
#     Downloading openai-1.51.2-py3-none-any.whl.metadata (24 kB)
#   Collecting requests (from -r requirements.txt (line 4))
#     Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
#   Collecting prompty==0.1.24 (from prompty[azure]==0.1.24->-r requirements.txt (
#   line 5))
#     Downloading prompty-0.1.24-py2.py3-none-any.whl.metadata (9.0 kB)
#
#   Collecting openai (from -r requirements.txt (line 3))──────────────────────
#     Downloading openai-1.51.2-py3-none-any.whl.metadata (24 kB)
#   Collecting requests (from -r requirements.txt (line 4))
#     Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
#   Collecting prompty==0.1.24 (from prompty[azure]==0.1.24->-r requirements.txt (
#   line 5))
#     Downloading prompty-0.1.24-py2.py3-none-any.whl.metadata (9.0 kB)
#   Collecting promptflow (from -r requirements.txt (line 6))
#
#     Downloading openai-1.51.2-py3-none-any.whl.metadata (24 kB)──────────────
#   Collecting requests (from -r requirements.txt (line 4))
#     Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
#   Collecting prompty==0.1.24 (from prompty[azure]==0.1.24->-r requirements.txt (
#   line 5))
#     Downloading prompty-0.1.24-py2.py3-none-any.whl.metadata (9.0 kB)
#   Collecting promptflow (from -r requirements.txt (line 6))
#     Downloading promptflow-1.16.1-py3-none-any.whl.metadata (26 kB)
#
#   Collecting requests (from -r requirements.txt (line 4))────────────────────
#     Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
#   Collecting prompty==0.1.24 (from prompty[azure]==0.1.24->-r requirements.txt (
#   line 5))
#     Downloading prompty-0.1.24-py2.py3-none-any.whl.metadata (9.0 kB)
#   Collecting promptflow (from -r requirements.txt (line 6))
#     Downloading promptflow-1.16.1-py3-none-any.whl.metadata (26 kB)
#   Collecting promptflow-evals (from -r requirements.txt (line 7))
#
#     Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)───────────
#   Collecting prompty==0.1.24 (from prompty[azure]==0.1.24->-r requirements.txt (
#   line 5))
#     Downloading prompty-0.1.24-py2.py3-none-any.whl.metadata (9.0 kB)
#   Collecting promptflow (from -r requirements.txt (line 6))
#     Downloading promptflow-1.16.1-py3-none-any.whl.metadata (26 kB)
#   Collecting promptflow-evals (from -r requirements.txt (line 7))
#     Downloading promptflow_evals-0.3.2-py3-none-any.whl.metadata (4.3 kB)
#
#   Collecting prompty==0.1.24 (from prompty[azure]==0.1.24->-r requirements.txt (
#   line 5))
#     Downloading prompty-0.1.24-py2.py3-none-any.whl.metadata (9.0 kB)
#   Collecting promptflow (from -r requirements.txt (line 6))
#     Downloading promptflow-1.16.1-py3-none-any.whl.metadata (26 kB)
#   Collecting promptflow-evals (from -r requirements.txt (line 7))
#     Downloading promptflow_evals-0.3.2-py3-none-any.whl.metadata (4.3 kB)
#   Collecting pandas (from -r requirements.txt (line 8))
#
#     Downloading prompty-0.1.24-py2.py3-none-any.whl.metadata (9.0 kB)────────
#   Collecting promptflow (from -r requirements.txt (line 6))
#     Downloading promptflow-1.16.1-py3-none-any.whl.metadata (26 kB)
#   Collecting promptflow-evals (from -r requirements.txt (line 7))
#     Downloading promptflow_evals-0.3.2-py3-none-any.whl.metadata (4.3 kB)
#   Collecting pandas (from -r requirements.txt (line 8))
#     Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86
#   _64.whl.metadata (89 kB)
#
#   Collecting promptflow-evals (from -r requirements.txt (line 7))────────────
#     Downloading promptflow_evals-0.3.2-py3-none-any.whl.metadata (4.3 kB)
#   Collecting pandas (from -r requirements.txt (line 8))
#     Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86
#   _64.whl.metadata (89 kB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━�
#   ��━━━━━━━━━━━━━━━ 89.9/89.9 kB 30.8 MB/s eta 0:0
#   0:00
#
#   Collecting pandas (from -r requirements.txt (line 8))──────────────────────
#     Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86
#   _64.whl.metadata (89 kB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━�
#   ��━━━━━━━━━━━━━━━ 89.9/89.9 kB 30.8 MB/s eta 0:0
#   0:00
#   Collecting azure-monitor-opentelemetry-exporter (from -r requirements.txt (lin
#   e 9))
#
#   _64.whl.metadata (89 kB)───────────────────────────────────────────────────
#        ━━━━━━━━━━━━━━━━━━━━━━━━�
#   ��━━━━━━━━━━━━━━━ 89.9/89.9 kB 30.8 MB/s eta 0:0
#   0:00
#   Collecting azure-monitor-opentelemetry-exporter (from -r requirements.txt (lin
#   e 9))
#     Downloading azure_monitor_opentelemetry_exporter-1.0.0b31-py2.py3-none-any.w
#   hl.metadata (32 kB)
#
#   ��━━━━━━━━━━━━━━━ 89.9/89.9 kB 30.8 MB/s eta 0:0───────────────────────────
#   0:00
#   Collecting azure-monitor-opentelemetry-exporter (from -r requirements.txt (lin
#   e 9))
#     Downloading azure_monitor_opentelemetry_exporter-1.0.0b31-py2.py3-none-any.w
#   hl.metadata (32 kB)
#   Collecting opentelemetry-instrumentation-fastapi (from -r requirements.txt (li
#   ne 10))
#
#   Collecting azure-monitor-opentelemetry-exporter (from -r requirements.txt (lin
#   e 9))
#     Downloading azure_monitor_opentelemetry_exporter-1.0.0b31-py2.py3-none-any.w
#   hl.metadata (32 kB)
#   Collecting opentelemetry-instrumentation-fastapi (from -r requirements.txt (li
#   ne 10))
#     Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl.me
#   tadata (2.1 kB)
#
#   e 9))A─────────────────────────────────────────────────────────────────────
#     Downloading azure_monitor_opentelemetry_exporter-1.0.0b31-py2.py3-none-any.w
#   hl.metadata (32 kB)
#   Collecting opentelemetry-instrumentation-fastapi (from -r requirements.txt (li
#   ne 10))
#     Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl.me
#   tadata (2.1 kB)
#   Collecting jsonlines (from -r requirements.txt (line 11))
#
#     Downloading azure_monitor_opentelemetry_exporter-1.0.0b31-py2.py3-none-any.w
#   hl.metadata (32 kB)
#   Collecting opentelemetry-instrumentation-fastapi (from -r requirements.txt (li
#   ne 10))
#     Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl.me
#   tadata (2.1 kB)
#   Collecting jsonlines (from -r requirements.txt (line 11))
#     Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
#
#   hl.metadata (32 kB)────────────────────────────────────────────────────────
#   Collecting opentelemetry-instrumentation-fastapi (from -r requirements.txt (li
#   ne 10))
#     Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl.me
#   tadata (2.1 kB)
#   Collecting jsonlines (from -r requirements.txt (line 11))
#     Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
#   Collecting python-dotenv==1.0.1 (from -r requirements.txt (line 12))
#
#   Collecting opentelemetry-instrumentation-fastapi (from -r requirements.txt (li
#   ne 10))
#     Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl.me
#   tadata (2.1 kB)
#   Collecting jsonlines (from -r requirements.txt (line 11))
#     Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
#   Collecting python-dotenv==1.0.1 (from -r requirements.txt (line 12))
#     Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
#
#   ne 10))────────────────────────────────────────────────────────────────────
#     Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl.me
#   tadata (2.1 kB)
#   Collecting jsonlines (from -r requirements.txt (line 11))
#     Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
#   Collecting python-dotenv==1.0.1 (from -r requirements.txt (line 12))
#     Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
#   Collecting azure-search-documents==11.4.0 (from -r requirements.txt (line 13))
#
#     Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl.me
#   tadata (2.1 kB)
#   Collecting jsonlines (from -r requirements.txt (line 11))
#     Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
#   Collecting python-dotenv==1.0.1 (from -r requirements.txt (line 12))
#     Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
#   Collecting azure-search-documents==11.4.0 (from -r requirements.txt (line 13))
#     Downloading azure_search_documents-11.4.0-py3-none-any.whl.metadata (22 kB)
#
#   tadata (2.1 kB)────────────────────────────────────────────────────────────
#   Collecting jsonlines (from -r requirements.txt (line 11))
#     Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
#   Collecting python-dotenv==1.0.1 (from -r requirements.txt (line 12))
#     Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
#   Collecting azure-search-documents==11.4.0 (from -r requirements.txt (line 13))
#     Downloading azure_search_documents-11.4.0-py3-none-any.whl.metadata (22 kB)
#   Collecting gunicorn==21.2.0 (from -r requirements.txt (line 14))
#
#   Collecting jsonlines (from -r requirements.txt (line 11))──────────────────
#     Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
#   Collecting python-dotenv==1.0.1 (from -r requirements.txt (line 12))
#     Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
#   Collecting azure-search-documents==11.4.0 (from -r requirements.txt (line 13))
#     Downloading azure_search_documents-11.4.0-py3-none-any.whl.metadata (22 kB)
#   Collecting gunicorn==21.2.0 (from -r requirements.txt (line 14))
#     Downloading gunicorn-21.2.0-py3-none-any.whl.metadata (4.1 kB)
#
#     Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)───────────
#   Collecting python-dotenv==1.0.1 (from -r requirements.txt (line 12))
#     Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
#   Collecting azure-search-documents==11.4.0 (from -r requirements.txt (line 13))
#     Downloading azure_search_documents-11.4.0-py3-none-any.whl.metadata (22 kB)
#   Collecting gunicorn==21.2.0 (from -r requirements.txt (line 14))
#     Downloading gunicorn-21.2.0-py3-none-any.whl.metadata (4.1 kB)
#   Collecting jupyter (from -r requirements.txt (line 15))
#
#   Collecting python-dotenv==1.0.1 (from -r requirements.txt (line 12))───────
#     Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
#   Collecting azure-search-documents==11.4.0 (from -r requirements.txt (line 13))
#     Downloading azure_search_documents-11.4.0-py3-none-any.whl.metadata (22 kB)
#   Collecting gunicorn==21.2.0 (from -r requirements.txt (line 14))
#     Downloading gunicorn-21.2.0-py3-none-any.whl.metadata (4.1 kB)
#   Collecting jupyter (from -r requirements.txt (line 15))
#     Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
#
#     Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)────────
#   Collecting azure-search-documents==11.4.0 (from -r requirements.txt (line 13))
#     Downloading azure_search_documents-11.4.0-py3-none-any.whl.metadata (22 kB)
#   Collecting gunicorn==21.2.0 (from -r requirements.txt (line 14))
#     Downloading gunicorn-21.2.0-py3-none-any.whl.metadata (4.1 kB)
#   Collecting jupyter (from -r requirements.txt (line 15))
#     Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
#   Collecting opentelemetry-instrumentation (from -r requirements.txt (line 16))
#
#     Downloading azure_search_documents-11.4.0-py3-none-any.whl.metadata (22 kB)
#   Collecting gunicorn==21.2.0 (from -r requirements.txt (line 14))
#     Downloading gunicorn-21.2.0-py3-none-any.whl.metadata (4.1 kB)
#   Collecting jupyter (from -r requirements.txt (line 15))
#     Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
#   Collecting opentelemetry-instrumentation (from -r requirements.txt (line 16))
#     Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl.metadata (
#   6.1 kB)
#
#   Collecting gunicorn==21.2.0 (from -r requirements.txt (line 14))───────────
#     Downloading gunicorn-21.2.0-py3-none-any.whl.metadata (4.1 kB)
#   Collecting jupyter (from -r requirements.txt (line 15))
#     Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
#   Collecting opentelemetry-instrumentation (from -r requirements.txt (line 16))
#     Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl.metadata (
#   6.1 kB)
#   Collecting azure-identity==1.17.1 (from -r requirements.txt (line 17))
#
#     Downloading gunicorn-21.2.0-py3-none-any.whl.metadata (4.1 kB)───────────
#   Collecting jupyter (from -r requirements.txt (line 15))
#     Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
#   Collecting opentelemetry-instrumentation (from -r requirements.txt (line 16))
#     Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl.metadata (
#   6.1 kB)
#   Collecting azure-identity==1.17.1 (from -r requirements.txt (line 17))
#     Downloading azure_identity-1.17.1-py3-none-any.whl.metadata (79 kB)
#
#   Collecting opentelemetry-instrumentation (from -r requirements.txt (line 16))
#     Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl.metadata (
#   6.1 kB)
#   Collecting azure-identity==1.17.1 (from -r requirements.txt (line 17))
#     Downloading azure_identity-1.17.1-py3-none-any.whl.metadata (79 kB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━�
#   ��━━━━━━━━━━━━━━ 79.4/79.4 kB 204.6 MB/s eta 0:00:
#   00
#
#   6.1 kB)────────────────────────────────────────────────────────────────────
#   Collecting azure-identity==1.17.1 (from -r requirements.txt (line 17))
#     Downloading azure_identity-1.17.1-py3-none-any.whl.metadata (79 kB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━�
#   ��━━━━━━━━━━━━━━ 79.4/79.4 kB 204.6 MB/s eta 0:00:
#   00
#   Collecting pyyaml>=6.0.1 (from prompty==0.1.24->prompty[azure]==0.1.24->-r req
#   uirements.txt (line 5))
#
#     Downloading azure_identity-1.17.1-py3-none-any.whl.metadata (79 kB)──────
#        ━━━━━━━━━━━━━━━━━━━━━━━━�
#   ��━━━━━━━━━━━━━━ 79.4/79.4 kB 204.6 MB/s eta 0:00:
#   00
#   Collecting pyyaml>=6.0.1 (from prompty==0.1.24->prompty[azure]==0.1.24->-r req
#   uirements.txt (line 5))
#     Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86
#   _64.whl.metadata (2.1 kB)
#
#   ��━━━━━━━━━━━━━━ 79.4/79.4 kB 204.6 MB/s eta 0:00:─────────────────────────
#   00
#   Collecting pyyaml>=6.0.1 (from prompty==0.1.24->prompty[azure]==0.1.24->-r req
#   uirements.txt (line 5))
#     Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86
#   _64.whl.metadata (2.1 kB)
#   Collecting pydantic>=2.8.2 (from prompty==0.1.24->prompty[azure]==0.1.24->-r r
#   equirements.txt (line 5))
#
#   00─────────────────────────────────────────────────────────────────────
#   Collecting pyyaml>=6.0.1 (from prompty==0.1.24->prompty[azure]==0.1.24->-r req
#   uirements.txt (line 5))
#     Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86
#   _64.whl.metadata (2.1 kB)
#   Collecting pydantic>=2.8.2 (from prompty==0.1.24->prompty[azure]==0.1.24->-r r
#   equirements.txt (line 5))
#     Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
#
#   uirements.txt (line 5))────────────────────────────────────────────────────
#     Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86
#   _64.whl.metadata (2.1 kB)
#   Collecting pydantic>=2.8.2 (from prompty==0.1.24->prompty[azure]==0.1.24->-r r
#   equirements.txt (line 5))
#     Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━�
#   ��━━━━━━━━━━━━ 149.4/149.4 kB 240.7 MB/s eta 0:00:00
#
#   _64.whl.metadata (2.1 kB)──────────────────────────────────────────────────
#   Collecting pydantic>=2.8.2 (from prompty==0.1.24->prompty[azure]==0.1.24->-r r
#   equirements.txt (line 5))
#     Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━�
#   ��━━━━━━━━━━━━ 149.4/149.4 kB 240.7 MB/s eta 0:00:00
#   Collecting jinja2>=3.1.4 (from prompty==0.1.24->prompty[azure]==0.1.24->-r req
#   uirements.txt (line 5))
#
#   Collecting pydantic>=2.8.2 (from prompty==0.1.24->prompty[azure]==0.1.24->-r r
#   equirements.txt (line 5))
#     Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━�
#   ��━━━━━━━━━━━━ 149.4/149.4 kB 240.7 MB/s eta 0:00:00
#   Collecting jinja2>=3.1.4 (from prompty==0.1.24->prompty[azure]==0.1.24->-r req
#   uirements.txt (line 5))
#     Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
#
#     Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)────────────
#        ━━━━━━━━━━━━━━━━━━━━━━━━�
#   ��━━━━━━━━━━━━ 149.4/149.4 kB 240.7 MB/s eta 0:00:00
#   Collecting jinja2>=3.1.4 (from prompty==0.1.24->prompty[azure]==0.1.24->-r req
#   uirements.txt (line 5))
#     Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
#   Collecting click>=8.1.7 (from prompty==0.1.24->prompty[azure]==0.1.24->-r requ
#   irements.txt (line 5))
#
#        ━━━━━━━━━━━━━━━━━━━━━━━━�─────────────────────────────────────────────
#   ��━━━━━━━━━━━━ 149.4/149.4 kB 240.7 MB/s eta 0:00:00
#   Collecting jinja2>=3.1.4 (from prompty==0.1.24->prompty[azure]==0.1.24->-r req
#   uirements.txt (line 5))
#     Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
#   Collecting click>=8.1.7 (from prompty==0.1.24->prompty[azure]==0.1.24->-r requ
#   irements.txt (line 5))
#     Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
#
#   Collecting jinja2>=3.1.4 (from prompty==0.1.24->prompty[azure]==0.1.24->-r req
#   uirements.txt (line 5))
#     Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
#   Collecting click>=8.1.7 (from prompty==0.1.24->prompty[azure]==0.1.24->-r requ
#   irements.txt (line 5))
#     Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
#   Collecting azure-core<2.0.0,>=1.28.0 (from azure-search-documents==11.4.0->-r
#   requirements.txt (line 13))
#
#   uirements.txt (line 5))────────────────────────────────────────────────────
#     Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
#   Collecting click>=8.1.7 (from prompty==0.1.24->prompty[azure]==0.1.24->-r requ
#   irements.txt (line 5))
#     Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
#   Collecting azure-core<2.0.0,>=1.28.0 (from azure-search-documents==11.4.0->-r
#   requirements.txt (line 13))
#     Downloading azure_core-1.31.0-py3-none-any.whl.metadata (39 kB)
#
#   Collecting click>=8.1.7 (from prompty==0.1.24->prompty[azure]==0.1.24->-r requ
#   irements.txt (line 5))
#     Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
#   Collecting azure-core<2.0.0,>=1.28.0 (from azure-search-documents==11.4.0->-r
#   requirements.txt (line 13))
#     Downloading azure_core-1.31.0-py3-none-any.whl.metadata (39 kB)
#   Collecting azure-common~=1.1 (from azure-search-documents==11.4.0->-r requirem
#   ents.txt (line 13))
#
#   irements.txt (line 5))─────────────────────────────────────────────────────
#     Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
#   Collecting azure-core<2.0.0,>=1.28.0 (from azure-search-documents==11.4.0->-r
#   requirements.txt (line 13))
#     Downloading azure_core-1.31.0-py3-none-any.whl.metadata (39 kB)
#   Collecting azure-common~=1.1 (from azure-search-documents==11.4.0->-r requirem
#   ents.txt (line 13))
#     Downloading azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
#
#   Collecting azure-core<2.0.0,>=1.28.0 (from azure-search-documents==11.4.0->-r
#   requirements.txt (line 13))
#     Downloading azure_core-1.31.0-py3-none-any.whl.metadata (39 kB)
#   Collecting azure-common~=1.1 (from azure-search-documents==11.4.0->-r requirem
#   ents.txt (line 13))
#     Downloading azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
#   Collecting isodate>=0.6.0 (from azure-search-documents==11.4.0->-r requirement
#   s.txt (line 13))
#
#   requirements.txt (line 13))────────────────────────────────────────────────
#     Downloading azure_core-1.31.0-py3-none-any.whl.metadata (39 kB)
#   Collecting azure-common~=1.1 (from azure-search-documents==11.4.0->-r requirem
#   ents.txt (line 13))
#     Downloading azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
#   Collecting isodate>=0.6.0 (from azure-search-documents==11.4.0->-r requirement
#   s.txt (line 13))
#     Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
#
#     Downloading azure_core-1.31.0-py3-none-any.whl.metadata (39 kB)──────────
#   Collecting azure-common~=1.1 (from azure-search-documents==11.4.0->-r requirem
#   ents.txt (line 13))
#     Downloading azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
#   Collecting isodate>=0.6.0 (from azure-search-documents==11.4.0->-r requirement
#   s.txt (line 13))
#     Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
#   Collecting packaging (from gunicorn==21.2.0->-r requirements.txt (line 14))
#
#   Collecting azure-common~=1.1 (from azure-search-documents==11.4.0->-r requirem
#   ents.txt (line 13))
#     Downloading azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
#   Collecting isodate>=0.6.0 (from azure-search-documents==11.4.0->-r requirement
#   s.txt (line 13))
#     Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
#   Collecting packaging (from gunicorn==21.2.0->-r requirements.txt (line 14))
#     Downloading packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
#
#     Downloading azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)───
#   Collecting isodate>=0.6.0 (from azure-search-documents==11.4.0->-r requirement
#   s.txt (line 13))
#     Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
#   Collecting packaging (from gunicorn==21.2.0->-r requirements.txt (line 14))
#     Downloading packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
#   Collecting cryptography>=2.5 (from azure-identity==1.17.1->-r requirements.txt
#    (line 17))
#
#   s.txt (line 13))───────────────────────────────────────────────────────────
#     Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
#   Collecting packaging (from gunicorn==21.2.0->-r requirements.txt (line 14))
#     Downloading packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
#   Collecting cryptography>=2.5 (from azure-identity==1.17.1->-r requirements.txt
#    (line 17))
#     Downloading cryptography-43.0.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata
#    (5.4 kB)
#
#   Collecting packaging (from gunicorn==21.2.0->-r requirements.txt (line 14))
#     Downloading packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
#   Collecting cryptography>=2.5 (from azure-identity==1.17.1->-r requirements.txt
#    (line 17))
#     Downloading cryptography-43.0.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata
#    (5.4 kB)
#   Collecting msal>=1.24.0 (from azure-identity==1.17.1->-r requirements.txt (lin
#   e 17))
#
#     Downloading packaging-24.1-py3-none-any.whl.metadata (3.2 kB)────────────
#   Collecting cryptography>=2.5 (from azure-identity==1.17.1->-r requirements.txt
#    (line 17))
#     Downloading cryptography-43.0.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata
#    (5.4 kB)
#   Collecting msal>=1.24.0 (from azure-identity==1.17.1->-r requirements.txt (lin
#   e 17))
#     Downloading msal-1.31.0-py3-none-any.whl.metadata (11 kB)
#
#    (line 17))────────────────────────────────────────────────────────────────
#     Downloading cryptography-43.0.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata
#    (5.4 kB)
#   Collecting msal>=1.24.0 (from azure-identity==1.17.1->-r requirements.txt (lin
#   e 17))
#     Downloading msal-1.31.0-py3-none-any.whl.metadata (11 kB)
#   Collecting msal-extensions>=0.3.0 (from azure-identity==1.17.1->-r requirement
#   s.txt (line 17))
#
#     Downloading cryptography-43.0.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata
#    (5.4 kB)
#   Collecting msal>=1.24.0 (from azure-identity==1.17.1->-r requirements.txt (lin
#   e 17))
#     Downloading msal-1.31.0-py3-none-any.whl.metadata (11 kB)
#   Collecting msal-extensions>=0.3.0 (from azure-identity==1.17.1->-r requirement
#   s.txt (line 17))
#     Downloading msal_extensions-1.2.0-py3-none-any.whl.metadata (7.6 kB)
#
#   Collecting msal>=1.24.0 (from azure-identity==1.17.1->-r requirements.txt (lin
#   e 17))
#     Downloading msal-1.31.0-py3-none-any.whl.metadata (11 kB)
#   Collecting msal-extensions>=0.3.0 (from azure-identity==1.17.1->-r requirement
#   s.txt (line 17))
#     Downloading msal_extensions-1.2.0-py3-none-any.whl.metadata (7.6 kB)
#   Collecting typing-extensions>=4.0.0 (from azure-identity==1.17.1->-r requireme
#   nts.txt (line 17))
#
#   e 17))─────────────────────────────────────────────────────────────────────
#     Downloading msal-1.31.0-py3-none-any.whl.metadata (11 kB)
#   Collecting msal-extensions>=0.3.0 (from azure-identity==1.17.1->-r requirement
#   s.txt (line 17))
#     Downloading msal_extensions-1.2.0-py3-none-any.whl.metadata (7.6 kB)
#   Collecting typing-extensions>=4.0.0 (from azure-identity==1.17.1->-r requireme
#   nts.txt (line 17))
#     Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
#
#   Collecting msal-extensions>=0.3.0 (from azure-identity==1.17.1->-r requirement
#   s.txt (line 17))
#     Downloading msal_extensions-1.2.0-py3-none-any.whl.metadata (7.6 kB)
#   Collecting typing-extensions>=4.0.0 (from azure-identity==1.17.1->-r requireme
#   nts.txt (line 17))
#     Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
#   Collecting starlette<0.39.0,>=0.37.2 (from fastapi->-r requirements.txt (line
#   1))
#
#   s.txt (line 17))───────────────────────────────────────────────────────────
#     Downloading msal_extensions-1.2.0-py3-none-any.whl.metadata (7.6 kB)
#   Collecting typing-extensions>=4.0.0 (from azure-identity==1.17.1->-r requireme
#   nts.txt (line 17))
#     Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
#   Collecting starlette<0.39.0,>=0.37.2 (from fastapi->-r requirements.txt (line
#   1))
#     Downloading starlette-0.38.6-py3-none-any.whl.metadata (6.0 kB)
#
#   Collecting typing-extensions>=4.0.0 (from azure-identity==1.17.1->-r requireme
#   nts.txt (line 17))
#     Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
#   Collecting starlette<0.39.0,>=0.37.2 (from fastapi->-r requirements.txt (line
#   1))
#     Downloading starlette-0.38.6-py3-none-any.whl.metadata (6.0 kB)
#   Collecting fastapi-cli>=0.0.5 (from fastapi-cli[standard]>=0.0.5; extra == "st
#   andard"->fastapi[standard]->-r requirements.txt (line 2))
#
#   nts.txt (line 17))─────────────────────────────────────────────────────────
#     Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
#   Collecting starlette<0.39.0,>=0.37.2 (from fastapi->-r requirements.txt (line
#   1))
#     Downloading starlette-0.38.6-py3-none-any.whl.metadata (6.0 kB)
#   Collecting fastapi-cli>=0.0.5 (from fastapi-cli[standard]>=0.0.5; extra == "st
#   andard"->fastapi[standard]->-r requirements.txt (line 2))
#     Downloading fastapi_cli-0.0.5-py3-none-any.whl.metadata (7.0 kB)
#
#   Collecting starlette<0.39.0,>=0.37.2 (from fastapi->-r requirements.txt (line
#   1))
#     Downloading starlette-0.38.6-py3-none-any.whl.metadata (6.0 kB)
#   Collecting fastapi-cli>=0.0.5 (from fastapi-cli[standard]>=0.0.5; extra == "st
#   andard"->fastapi[standard]->-r requirements.txt (line 2))
#     Downloading fastapi_cli-0.0.5-py3-none-any.whl.metadata (7.0 kB)
#   Collecting httpx>=0.23.0 (from fastapi[standard]->-r requirements.txt (line 2)
#   )
#
#   1))[1A─────────────────────────────────────────────────────────────────────
#     Downloading starlette-0.38.6-py3-none-any.whl.metadata (6.0 kB)
#   Collecting fastapi-cli>=0.0.5 (from fastapi-cli[standard]>=0.0.5; extra == "st
#   andard"->fastapi[standard]->-r requirements.txt (line 2))
#     Downloading fastapi_cli-0.0.5-py3-none-any.whl.metadata (7.0 kB)
#   Collecting httpx>=0.23.0 (from fastapi[standard]->-r requirements.txt (line 2)
#   )
#     Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
#
#   Collecting fastapi-cli>=0.0.5 (from fastapi-cli[standard]>=0.0.5; extra == "st
#   andard"->fastapi[standard]->-r requirements.txt (line 2))
#     Downloading fastapi_cli-0.0.5-py3-none-any.whl.metadata (7.0 kB)
#   Collecting httpx>=0.23.0 (from fastapi[standard]->-r requirements.txt (line 2)
#   )
#     Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
#   Collecting python-multipart>=0.0.7 (from fastapi[standard]->-r requirements.tx
#   t (line 2))
#
#   andard"->fastapi[standard]->-r requirements.txt (line 2))──────────────────
#     Downloading fastapi_cli-0.0.5-py3-none-any.whl.metadata (7.0 kB)
#   Collecting httpx>=0.23.0 (from fastapi[standard]->-r requirements.txt (line 2)
#   )
#     Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
#   Collecting python-multipart>=0.0.7 (from fastapi[standard]->-r requirements.tx
#   t (line 2))
#     Downloading python_multipart-0.0.12-py3-none-any.whl.metadata (1.9 kB)
#
#   Collecting httpx>=0.23.0 (from fastapi[standard]->-r requirements.txt (line 2)
#   )
#     Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
#   Collecting python-multipart>=0.0.7 (from fastapi[standard]->-r requirements.tx
#   t (line 2))
#     Downloading python_multipart-0.0.12-py3-none-any.whl.metadata (1.9 kB)
#   Collecting email-validator>=2.0.0 (from fastapi[standard]->-r requirements.txt
#    (line 2))
#
#   )A─────────────────────────────────────────────────────────────────────
#     Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
#   Collecting python-multipart>=0.0.7 (from fastapi[standard]->-r requirements.tx
#   t (line 2))
#     Downloading python_multipart-0.0.12-py3-none-any.whl.metadata (1.9 kB)
#   Collecting email-validator>=2.0.0 (from fastapi[standard]->-r requirements.txt
#    (line 2))
#     Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
#
#   Collecting python-multipart>=0.0.7 (from fastapi[standard]->-r requirements.tx
#   t (line 2))
#     Downloading python_multipart-0.0.12-py3-none-any.whl.metadata (1.9 kB)
#   Collecting email-validator>=2.0.0 (from fastapi[standard]->-r requirements.txt
#    (line 2))
#     Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
#   Collecting uvicorn>=0.12.0 (from uvicorn[standard]>=0.12.0; extra == "standard
#   "->fastapi[standard]->-r requirements.txt (line 2))
#
#   t (line 2))────────────────────────────────────────────────────────────────
# ...
#         "scale": {
#           "maxReplicas": 10,
#           "minReplicas": 1,
#           "rules": null
#         },
#         "serviceBinds": null,
#         "terminationGracePeriodSeconds": null,
#
#         "scale": {───────────────────────────────────────────────────────────
#           "maxReplicas": 10,
#           "minReplicas": 1,
#           "rules": null
#         },
#         "serviceBinds": null,
#         "terminationGracePeriodSeconds": null,
#         "volumes": null
#
#           "maxReplicas": 10,─────────────────────────────────────────────────
#           "minReplicas": 1,
#           "rules": null
#         },
#         "serviceBinds": null,
#         "terminationGracePeriodSeconds": null,
#         "volumes": null
#       },
#
#           "minReplicas": 1,──────────────────────────────────────────────────
#           "rules": null
#         },
#         "serviceBinds": null,
#         "terminationGracePeriodSeconds": null,
#         "volumes": null
#       },
#       "workloadProfileName": null
#
#           "rules": null──────────────────────────────────────────────────────
#         },
#         "serviceBinds": null,
#         "terminationGracePeriodSeconds": null,
#         "volumes": null
#       },
#       "workloadProfileName": null
#     },
#
#         },───────────────────────────────────────────────────────────────────
#         "serviceBinds": null,
#         "terminationGracePeriodSeconds": null,
#         "volumes": null
#       },
#       "workloadProfileName": null
#     },
#     "resourceGroup": "rg-AITOUR44726673",
#
#         "serviceBinds": null,────────────────────────────────────────────────
#         "terminationGracePeriodSeconds": null,
#         "volumes": null
#       },
#       "workloadProfileName": null
#     },
#     "resourceGroup": "rg-AITOUR44726673",
#     "systemData": {
#
#         "terminationGracePeriodSeconds": null,───────────────────────────────
#         "volumes": null
#       },
#       "workloadProfileName": null
#     },
#     "resourceGroup": "rg-AITOUR44726673",
#     "systemData": {
#       "createdAt": "2024-10-11T09:58:05.7413134",
#
#         "volumes": null──────────────────────────────────────────────────────
#       },
#       "workloadProfileName": null
#     },
#     "resourceGroup": "rg-AITOUR44726673",
#     "systemData": {
#       "createdAt": "2024-10-11T09:58:05.7413134",
#       "createdBy": "45587fa8-5f05-46d9-8d71-595d74062152",
#
#       },─────────────────────────────────────────────────────────────────────
#       "workloadProfileName": null
#     },
#     "resourceGroup": "rg-AITOUR44726673",
#     "systemData": {
#       "createdAt": "2024-10-11T09:58:05.7413134",
#       "createdBy": "45587fa8-5f05-46d9-8d71-595d74062152",
#       "createdByType": "Application",
#
#       "workloadProfileName": null────────────────────────────────────────────
#     },
#     "resourceGroup": "rg-AITOUR44726673",
#     "systemData": {
#       "createdAt": "2024-10-11T09:58:05.7413134",
#       "createdBy": "45587fa8-5f05-46d9-8d71-595d74062152",
#       "createdByType": "Application",
#       "lastModifiedAt": "2024-10-11T10:24:35.5249623",
#
#     },1A─────────────────────────────────────────────────────────────────────
#     "resourceGroup": "rg-AITOUR44726673",
#     "systemData": {
#       "createdAt": "2024-10-11T09:58:05.7413134",
#       "createdBy": "45587fa8-5f05-46d9-8d71-595d74062152",
#       "createdByType": "Application",
#       "lastModifiedAt": "2024-10-11T10:24:35.5249623",
#       "lastModifiedBy": "User1-44726673@LODSPRODMCA.onmicrosoft.com",
#
#     "resourceGroup": "rg-AITOUR44726673",────────────────────────────────────
#     "systemData": {
#       "createdAt": "2024-10-11T09:58:05.7413134",
#       "createdBy": "45587fa8-5f05-46d9-8d71-595d74062152",
#       "createdByType": "Application",
#       "lastModifiedAt": "2024-10-11T10:24:35.5249623",
#       "lastModifiedBy": "User1-44726673@LODSPRODMCA.onmicrosoft.com",
#       "lastModifiedByType": "User"
#
#     "systemData": {──────────────────────────────────────────────────────────
#       "createdAt": "2024-10-11T09:58:05.7413134",
#       "createdBy": "45587fa8-5f05-46d9-8d71-595d74062152",
#       "createdByType": "Application",
#       "lastModifiedAt": "2024-10-11T10:24:35.5249623",
#       "lastModifiedBy": "User1-44726673@LODSPRODMCA.onmicrosoft.com",
#       "lastModifiedByType": "User"
#     },
#
#       "createdAt": "2024-10-11T09:58:05.7413134",────────────────────────────
#       "createdBy": "45587fa8-5f05-46d9-8d71-595d74062152",
#       "createdByType": "Application",
#       "lastModifiedAt": "2024-10-11T10:24:35.5249623",
#       "lastModifiedBy": "User1-44726673@LODSPRODMCA.onmicrosoft.com",
#       "lastModifiedByType": "User"
#     },
#     "tags": {
#
#       "createdBy": "45587fa8-5f05-46d9-8d71-595d74062152",───────────────────
#       "createdByType": "Application",
#       "lastModifiedAt": "2024-10-11T10:24:35.5249623",
#       "lastModifiedBy": "User1-44726673@LODSPRODMCA.onmicrosoft.com",
#       "lastModifiedByType": "User"
#     },
#     "tags": {
#       "azd-env-name": "AITOUR44726673",
#
#       "createdByType": "Application",────────────────────────────────────────
#       "lastModifiedAt": "2024-10-11T10:24:35.5249623",
#       "lastModifiedBy": "User1-44726673@LODSPRODMCA.onmicrosoft.com",
#       "lastModifiedByType": "User"
#     },
#     "tags": {
#       "azd-env-name": "AITOUR44726673",
#       "azd-service-name": "web"
#
#       "lastModifiedAt": "2024-10-11T10:24:35.5249623",───────────────────────
#       "lastModifiedBy": "User1-44726673@LODSPRODMCA.onmicrosoft.com",
#       "lastModifiedByType": "User"
#     },
#     "tags": {
#       "azd-env-name": "AITOUR44726673",
#       "azd-service-name": "web"
#     },
#
#       "lastModifiedBy": "User1-44726673@LODSPRODMCA.onmicrosoft.com",────────
#       "lastModifiedByType": "User"
#     },
#     "tags": {
#       "azd-env-name": "AITOUR44726673",
#       "azd-service-name": "web"
#     },
#     "type": "Microsoft.App/containerApps"
#
#       "lastModifiedByType": "User"───────────────────────────────────────────
#     },
#     "tags": {
#       "azd-env-name": "AITOUR44726673",
#       "azd-service-name": "web"
#     },
#     "type": "Microsoft.App/containerApps"
#   }
#
#     },1A─────────────────────────────────────────────────────────────────────
#     "tags": {
#       "azd-env-name": "AITOUR44726673",
#       "azd-service-name": "web"
#     },
#     "type": "Microsoft.App/containerApps"
#   }
#   {
#
#     "tags": {────────────────────────────────────────────────────────────────
#       "azd-env-name": "AITOUR44726673",
#       "azd-service-name": "web"
#     },
#     "type": "Microsoft.App/containerApps"
#   }
#   {
#     "additionalPortMappings": null,
#
#       "azd-env-name": "AITOUR44726673",──────────────────────────────────────
#       "azd-service-name": "web"
#     },
#     "type": "Microsoft.App/containerApps"
#   }
#   {
#     "additionalPortMappings": null,
#     "allowInsecure": false,
#
#       "azd-service-name": "web"──────────────────────────────────────────────
#     },
#     "type": "Microsoft.App/containerApps"
#   }
#   {
#     "additionalPortMappings": null,
#     "allowInsecure": false,
#     "clientCertificateMode": null,
#
#     },1A─────────────────────────────────────────────────────────────────────
#     "type": "Microsoft.App/containerApps"
#   }
#   {
#     "additionalPortMappings": null,
#     "allowInsecure": false,
#     "clientCertificateMode": null,
#     "corsPolicy": {
#
#     "type": "Microsoft.App/containerApps"────────────────────────────────────
#   }
#   {
#     "additionalPortMappings": null,
#     "allowInsecure": false,
#     "clientCertificateMode": null,
#     "corsPolicy": {
#       "allowCredentials": false,
#
#   }A─────────────────────────────────────────────────────────────────────
#   {
#     "additionalPortMappings": null,
#     "allowInsecure": false,
#     "clientCertificateMode": null,
#     "corsPolicy": {
#       "allowCredentials": false,
#       "allowedHeaders": [
#
#   {A─────────────────────────────────────────────────────────────────────
#     "additionalPortMappings": null,
#     "allowInsecure": false,
#     "clientCertificateMode": null,
#     "corsPolicy": {
#       "allowCredentials": false,
#       "allowedHeaders": [
#         "*"
#
#     "additionalPortMappings": null,──────────────────────────────────────────
#     "allowInsecure": false,
#     "clientCertificateMode": null,
#     "corsPolicy": {
#       "allowCredentials": false,
#       "allowedHeaders": [
#         "*"
#       ],
#
#     "allowInsecure": false,──────────────────────────────────────────────────
#     "clientCertificateMode": null,
#     "corsPolicy": {
#       "allowCredentials": false,
#       "allowedHeaders": [
#         "*"
#       ],
#       "allowedMethods": null,
#
#     "clientCertificateMode": null,───────────────────────────────────────────
#     "corsPolicy": {
#       "allowCredentials": false,
#       "allowedHeaders": [
#         "*"
#       ],
#       "allowedMethods": null,
#       "allowedOrigins": [
#
#     "corsPolicy": {──────────────────────────────────────────────────────────
#       "allowCredentials": false,
#       "allowedHeaders": [
#         "*"
#       ],
#       "allowedMethods": null,
#       "allowedOrigins": [
#         "https://portal.azure.com",
#
#       "allowCredentials": false,─────────────────────────────────────────────
#       "allowedHeaders": [
#         "*"
#       ],
#       "allowedMethods": null,
#       "allowedOrigins": [
#         "https://portal.azure.com",
#         "https://ms.portal.azure.com"
#
#       "allowedHeaders": [────────────────────────────────────────────────────
#         "*"
#       ],
#       "allowedMethods": null,
#       "allowedOrigins": [
#         "https://portal.azure.com",
#         "https://ms.portal.azure.com"
#       ],
#
#         "*"──────────────────────────────────────────────────────────────────
#       ],
#       "allowedMethods": null,
#       "allowedOrigins": [
#         "https://portal.azure.com",
#         "https://ms.portal.azure.com"
#       ],
#       "exposeHeaders": null,
#
#       ],─────────────────────────────────────────────────────────────────────
#       "allowedMethods": null,
#       "allowedOrigins": [
#         "https://portal.azure.com",
#         "https://ms.portal.azure.com"
#       ],
#       "exposeHeaders": null,
#       "maxAge": null
#
#       "allowedMethods": null,────────────────────────────────────────────────
#       "allowedOrigins": [
#         "https://portal.azure.com",
#         "https://ms.portal.azure.com"
#       ],
#       "exposeHeaders": null,
#       "maxAge": null
#     },
#
#       "allowedOrigins": [────────────────────────────────────────────────────
#         "https://portal.azure.com",
#         "https://ms.portal.azure.com"
#       ],
#       "exposeHeaders": null,
#       "maxAge": null
#     },
#     "customDomains": null,
#
#         "https://portal.azure.com",──────────────────────────────────────────
#         "https://ms.portal.azure.com"
#       ],
#       "exposeHeaders": null,
#       "maxAge": null
#     },
#     "customDomains": null,
#     "exposedPort": 0,
#
#         "https://ms.portal.azure.com"────────────────────────────────────────
#       ],
#       "exposeHeaders": null,
#       "maxAge": null
#     },
#     "customDomains": null,
#     "exposedPort": 0,
#     "external": true,
#
#       ],─────────────────────────────────────────────────────────────────────
#       "exposeHeaders": null,
#       "maxAge": null
#     },
#     "customDomains": null,
#     "exposedPort": 0,
#     "external": true,
#     "fqdn": "agent-web.blackdune-45fa353d.canadaeast.azurecontainerapps.io",
#
#       "exposeHeaders": null,─────────────────────────────────────────────────
#       "maxAge": null
#     },
#     "customDomains": null,
#     "exposedPort": 0,
#     "external": true,
#     "fqdn": "agent-web.blackdune-45fa353d.canadaeast.azurecontainerapps.io",
#     "ipSecurityRestrictions": null,
#
#       "maxAge": null─────────────────────────────────────────────────────────
#     },
#     "customDomains": null,
#     "exposedPort": 0,
#     "external": true,
#     "fqdn": "agent-web.blackdune-45fa353d.canadaeast.azurecontainerapps.io",
#     "ipSecurityRestrictions": null,
#     "stickySessions": null,
#
#     },1A─────────────────────────────────────────────────────────────────────
#     "customDomains": null,
#     "exposedPort": 0,
#     "external": true,
#     "fqdn": "agent-web.blackdune-45fa353d.canadaeast.azurecontainerapps.io",
#     "ipSecurityRestrictions": null,
#     "stickySessions": null,
#     "targetPort": 80,
#
#     "customDomains": null,───────────────────────────────────────────────────
#     "exposedPort": 0,
#     "external": true,
#     "fqdn": "agent-web.blackdune-45fa353d.canadaeast.azurecontainerapps.io",
#     "ipSecurityRestrictions": null,
#     "stickySessions": null,
#     "targetPort": 80,
#     "traffic": [
#
#     "exposedPort": 0,────────────────────────────────────────────────────────
#     "external": true,
#     "fqdn": "agent-web.blackdune-45fa353d.canadaeast.azurecontainerapps.io",
#     "ipSecurityRestrictions": null,
#     "stickySessions": null,
#     "targetPort": 80,
#     "traffic": [
#       {
#
#     "external": true,────────────────────────────────────────────────────────
#     "fqdn": "agent-web.blackdune-45fa353d.canadaeast.azurecontainerapps.io",
#     "ipSecurityRestrictions": null,
#     "stickySessions": null,
#     "targetPort": 80,
#     "traffic": [
#       {
#         "latestRevision": true,
#
#     "fqdn": "agent-web.blackdune-45fa353d.canadaeast.azurecontainerapps.io",─
#     "ipSecurityRestrictions": null,
#     "stickySessions": null,
#     "targetPort": 80,
#     "traffic": [
#       {
#         "latestRevision": true,
#         "weight": 100
#
#     "ipSecurityRestrictions": null,──────────────────────────────────────────
#     "stickySessions": null,
#     "targetPort": 80,
#     "traffic": [
#       {
#         "latestRevision": true,
#         "weight": 100
#       }
#
#     "stickySessions": null,──────────────────────────────────────────────────
#     "targetPort": 80,
#     "traffic": [
#       {
#         "latestRevision": true,
#         "weight": 100
#       }
#     ],
#
#     "targetPort": 80,────────────────────────────────────────────────────────
#     "traffic": [
#       {
#         "latestRevision": true,
#         "weight": 100
#       }
#     ],
#     "transport": "Auto"
#
#     "traffic": [─────────────────────────────────────────────────────────────
#       {
#         "latestRevision": true,
#         "weight": 100
#       }
#     ],
#     "transport": "Auto"
#   }
#
#       {A─────────────────────────────────────────────────────────────────────
#         "latestRevision": true,
#         "weight": 100
#       }
#     ],
#     "transport": "Auto"
#   }
#   --- ✅ | 1. Post-provisioning - env configured ---
#
#         "latestRevision": true,──────────────────────────────────────────────
#         "weight": 100
#       }
#     ],
#     "transport": "Auto"
#   }
#   --- ✅ | 1. Post-provisioning - env configured ---
#   Installing dependencies from "requirements.txt"
#
#         "weight": 100────────────────────────────────────────────────────────
#       }
#     ],
#     "transport": "Auto"
#   }
#   --- ✅ | 1. Post-provisioning - env configured ---
#   Installing dependencies from "requirements.txt"
#   --- ✅ | 2. Post-provisioning - ready execute notebooks ---
#
#       }A─────────────────────────────────────────────────────────────────────
#     ],
#     "transport": "Auto"
#   }
#   --- ✅ | 1. Post-provisioning - env configured ---
#   Installing dependencies from "requirements.txt"
#   --- ✅ | 2. Post-provisioning - ready execute notebooks ---
#   Populating data ....
#
#     ],1A─────────────────────────────────────────────────────────────────────
#     "transport": "Auto"
#   }
#   --- ✅ | 1. Post-provisioning - env configured ---
#   Installing dependencies from "requirements.txt"
#   --- ✅ | 2. Post-provisioning - ready execute notebooks ---
#   Populating data ....
#   --- ✅ | 3. Post-provisioning - populated data ---
#
#   }A─────────────────────────────────────────────────────────────────────
#   --- ✅ | 1. Post-provisioning - env configured ---
#   Installing dependencies from "requirements.txt"
#   --- ✅ | 2. Post-provisioning - ready execute notebooks ---
#   Populating data ....
#   --- ✅ | 3. Post-provisioning - populated data ---
#   --- 🎉 | 4. Access your ACA deployed web app here: https://agent-web.blackdu
#   ne-45fa353d.canadaeast.azurecontainerapps.io
#
#   (✓) Done: Running 1 postprovision command hook(s) for project─────
#
# SUCCESS: Your hooks have been run successfully

# %% [markdown]
# You are now ready to start understanding and building Contoso Creative Writer!
#
# ## Part 2: Understanding and Building Contoso Creative Writer
#
# ### Learning Outcomes
# In this section we will focus on four key outcomes, each split into their own notebook:
#
# 1. [Understanding agents and prompt engineering with Prompty.](./workshop-1-intro.ipynb)
# 2. [Utilizing Prompty tracing for debugging and observability.](./workshop-2-tracing.ipynb)
# 3. [Building and running Contoso Creative Writer.](./workshop-3-build.ipynb)
# 4. [Setting up automated evaluations with GitHub Actions.](./workshop-4-ci-cd.ipynb)
#
# Open the [workshop-1-intro.ipynb](workshop-1-intro.ipynb) file to begin the first learning outcome!
